# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/therochvoices/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 802          803         1       1  Carter, Master. William Thornton II
# 289          290         1       3                 Connolly, Miss. Kate
# 107          108         1       3               Moss, Mr. Albert Johan
# 428          429         0       3                     Flynn, Mr. James
# 357          358         0       2            Funk, Miss. Annie Clemmer
#
#         Sex   Age  SibSp  Parch  Ticket     Fare    Cabin Embarked
# 802    male  11.0      1      2  113760  120.000  B96 B98        S
# 289  female  22.0      0      0  370373    7.750      NaN        Q
# 107    male   NaN      0      0  312991    7.775      NaN        S
# 428    male   NaN      0      0  364851    7.750      NaN        Q
# 357  female  38.0      0      0  237671   13.000      NaN        S

# %%
df['Title'] = df['Name'].apply(lambda name: name.split(',')[1].split('.')[0].strip())
test['Title'] = test['Name'].apply(lambda name: name.split(',')[1].split('.')[0].strip())

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 313          314         0       3  Hendekovic, Mr. Ignjac  male  28.0      0
#
#      Parch  Ticket    Fare Cabin Embarked Title
# 313      0  349243  7.8958   NaN        S    Mr

# %%
import seaborn as sns
royal = pd.crosstab(df['Title'], df['Survived'])
royal.div(royal.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(8,4))
plt.show()

# %%
normalized_titles = {
    "Capt":       "Officer",
    "Col":        "Officer",
    "Don":        "Royalty",
    "Dr":         "Officer",
    "Major":      "Officer",
    "Jonkheer":   "Royalty",
    "Sir" :       "Royalty",
    "Lady" :      "Royalty",
    "Master" :    "Master",
    "Miss" :      "Miss",
    "Mlle":       "Miss",
    "Mme":        "Mrs",
    "Mr" :        "Mr",
    "Mrs" :       "Mrs",
    "Ms":         "Mrs",
    "Rev":        "Officer",
    "the Countess":"Royalty",
    "Dona":     "Royalty"
}

# %%
df['Title'] = df['Title'].map(normalized_titles)
test['Title'] = test['Title'].map(normalized_titles)

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
#
#      Parch  Ticket  Fare Cabin Embarked Title
# 889      0  111369  30.0  C148        C    Mr

# %%
df.drop(['PassengerId', 'Name'], axis=1, inplace=True)
test.drop(['PassengerId', 'Name'], axis=1, inplace=True)

# %%
df.sample()
# Out:
#      Survived  Pclass   Sex  Age  SibSp  Parch    Ticket   Fare Cabin  \
# 201         0       3  male  NaN      8      2  CA. 2343  69.55   NaN
#
#     Embarked Title
# 201        S    Mr

# %%
test.isnull().any()
# Out:
# Pclass      False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Ticket      False
# Fare         True
# Cabin        True
# Embarked    False
# Title       False
# dtype: bool

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
test['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df['Family'] = df['SibSp'] + df['Parch'] + 1
test['Family'] = test['SibSp'] + test['Parch'] + 1

# %%
df.sample()
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  \
# 800         0       2  male  34.0      0      0  250647  13.0   NaN        S
#
#     Title  Family
# 800    Mr       1

# %%
x = df[['Sex', 'Age', 'Title', 'Family']]
y = df['Survived']

# %%
x_t = test[['Sex', 'Age', 'Title', 'Family']]

# %%
test.sample()
# Out:
#    Pclass   Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked Title  \
# 2       2  male  62.0      0      0  240276  9.6875   NaN        Q    Mr
#
#    Family
# 2       1

# %%
y.sample()
# Out:
# 230    1
# Name: Survived, dtype: int64

# %%
x_ = x.iloc[:, 0:4].values
x_test = x_t.iloc[:, 0:4].values

# %%
x_
# Out:
# array([['male', 22.0, 'Mr', 2],
#        ['female', 38.0, 'Mrs', 2],
#        ['female', 26.0, 'Miss', 1],
#        ...,
#        ['female', 28.0, 'Miss', 4],
#        ['male', 26.0, 'Mr', 1],
#        ['male', 32.0, 'Mr', 1]], dtype=object)

# %%
from  sklearn.preprocessing import LabelEncoder
lEncoder = LabelEncoder()
x_[:, 0] = lEncoder.fit_transform(x_[:, 0])
x_test[:,0] = lEncoder.fit_transform(x_test[:,0])

# %%
x_[:, 2] = lEncoder.fit_transform(x_[:, 2])
x_test[:, 2] = lEncoder.fit_transform(x_test[:, 2])

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder(categorical_features = [2])
x_ = onehotencoder.fit_transform(x_).toarray()
x_test = onehotencoder.fit_transform(x_test).toarray()

# %%
x_[3]
# Out:
# array([ 0.,  0.,  0.,  1.,  0.,  0.,  0., 35.,  2.])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_, y, test_size=.2, random_state=21)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(n_jobs=-1)
lr.fit(x_, y)
# Out:
# /home/therochvoices/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:1232: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = lr.predict(x_test)

# %%
test.sample()
# Out:
#      Pclass   Sex   Age  SibSp  Parch Ticket     Fare Cabin Embarked    Title  \
# 293       1  male  53.0      1      1  33638  81.8583   A34        S  Officer
#
#      Family
# 293       3

# %%
test = pd.read_csv('test.csv')
test.sample()
# Out:
#      PassengerId  Pclass                    Name     Sex   Age  SibSp  Parch  \
# 349         1241       2  Walcroft, Miss. Nellie  female  31.0      0      0
#
#            Ticket  Fare Cabin Embarked
# 349  F.C.C. 13528  21.0   NaN        S

# %%
test['Survived'] = y_pred

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_pred, y_test)

# %%
mat
# Out:
# array([[94, 20],
#        [11, 54]])

# %%
forrest_params = dict(     
    max_depth = [n for n in range(9, 14)],     
    min_samples_split = [n for n in range(4, 11)], 
    min_samples_leaf = [n for n in range(2, 5)],     
    n_estimators = [n for n in range(10, 60, 10)],
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
forest = RandomForestClassifier(n_jobs=-1)
forest_cv = GridSearchCV(estimator=forest, param_grid=forrest_params, cv=5, verbose=2) 

forest_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 525 candidates, totalling 2625 fits
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=10, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=20
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=20, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=20
# [CV]  max_depth=9, min_samples_leaf=2, min_samples_split=4, n_estimators=20, total=   0.2s
# [CV] max_depth=9, min_samples_leaf=2, min_samples_split

# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=9, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=10, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=20, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=30, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=40, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50, total=   0.2s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50, total=   0.3s
# [CV] max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV]  max_depth=13, min_samples_leaf=4, min_samples_split=10, n_estimators=50, total=   0.3s
# [Parallel(n_jobs=1)]: Done 2625 out of 2625 | elapsed: 15.7min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': [9, 10, 11, 12, 13], 'min_samples_split': [4, 5, 6, 7, 8, 9, 10], 'min_samples_leaf': [2, 3, 4], 'n_estimators': [10, 20, 30, 40, 50]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
print("Best score: {}".format(forest_cv.best_score_))
print("Optimal params: {}".format(forest_cv.best_estimator_))
# Out:
# Best score: 0.8286516853932584
# Optimal params: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=9, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=6,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
